# %%
import pandas as pd

# %%
# axis 행은 0 열은 1
price = pd.Series([2000, 3000, 4000, 5000])
price
# Out:
# 0    2000
# 1    3000
# 2    4000
# 3    5000
# dtype: int64

# %%
df = pd.DataFrame({
    "메뉴": ["아메리카노", "카페라떼", "카푸치노", "에스프레소"],
    "가격": [2000, 3000, 4000, 5000]
})

# %%
df[['메뉴']]
# Out:
#       메뉴
# 0  아메리카노
# 1   카페라떼
# 2   카푸치노
# 3  에스프레소

# %%
df.to_csv('temp.csv')

# %%
temp_df = pd.read_csv('temp.csv')

# %%
# index 제거는 필수
df.to_csv('menu.csv', index=False)
