# %% [markdown]
# [구글 코랩(Colab)에서 실행하기](https://colab.research.google.com/github/lovedlim/bigdata_analyst_cert_v2/blob/main/part3/ch6/ch6_ex_type3.ipynb)

# %% [markdown]
# ### Section1.

# %%
# 한 커피 제조회사에서는 새로 출시한 커피의 카페인 함량이 평균 95mg 미만이라고 주장했다.
# 그 주장이 사실인가를 알아보기 위해 25개의 커피 샘플을 무작위로 추출했다.
# 커피 제조회사의 주장이 타당한지를 유의수준 5%에서 검정하시오.
# - 귀무가설: u >= 95
# - 대립가설: u < 95
# 데이터
import pandas as pd
df = pd.DataFrame({
    'Caffeine(mg)': [
        94.2, 93.7, 95.5, 93.9, 94.0, 95.2, 94.7, 93.5, 92.8, 94.4,
        93.8, 94.6, 93.3, 95.1, 94.3, 94.9, 93.9, 94.8, 95.0, 94.2,
        93.7, 94.4, 95.1, 94.0, 93.6
    ]
})
# 1. 표본 데이터의 평균을 구하시오
print("1, ", df['Caffeine(mg)'].mean())

# 2. shapiro-wilk 검정의 p-value를 구하시오
from scipy import stats
print("2. ", stats.shapiro(df['Caffeine(mg)']))

# 3. 단일표본 t검정의 검정 통계량을 구하시오.
print("3. ", stats.ttest_1samp(df['Caffeine(mg)'], 95, alternative='less'))

# 4. 단일표본 t검정의 p-value를 구하시오.
print("4. ", format(stats.ttest_1samp(df['Caffeine(mg)'], 95, alternative='less')[1], ".6f"))

# 5. 유의수준 0.05하에서 귀무가설을 기준으로 검정 결과를 채택/기각 중 선택해 입력하시오.
print("5. 기각")
# Out:
# 1,  94.264
# 2.  ShapiroResult(statistic=np.float64(0.9826578166170536), pvalue=np.float64(0.9322031137746971))
# 3.  TtestResult(statistic=np.float64(-5.501737036221897), pvalue=np.float64(5.8686553916715e-06), df=np.int64(24))
# 4.  0.000006
# 5. 기각

# %%
# 1. 표본 평균
print(df.mean())

# 2. 정규성 검정
from scipy import stats
print(stats.shapiro(df['Caffeine(mg)']))

# 3~5.단일 표본 t-검정
print(stats.ttest_1samp(df['Caffeine(mg)'], 95, alternative='less'))
# Out:
# Caffeine(mg)    94.264
# dtype: float64
# ShapiroResult(statistic=0.9826578166170536, pvalue=0.9322031137746971)
# TtestResult(statistic=-5.501737036221897, pvalue=5.8686553916715e-06, df=24)

# %%
statistic, pvalue = stats.ttest_1samp(df['Caffeine(mg)'], 95, alternative='less')
print("{:.10f}".format(pvalue))
# Out:
# 0.0000058687

# %% [markdown]
# ### Section2.

# %%
# 스마트폰 배터리의 충전 시간을 줄이기 위한 새로운 충전기를 개발했다.
# 개발된 충전기의 효과를 검정하기 위해 스마트폰 사용자 집단을 두 그룹으로 나눠 한 그룹에는 새로운 충전기를 제공하고, 다른 그룹에는 기존의 충전기를 제공했다. -> 독립인 2 그룹
# 그 후 두 그룹의 평균 충전 완료 시간을 비교했다.
# 두 그룹 모두 충전 시간은 정규 분포를 따르며 분산은 같다고 가정한다.
# 새로운 충전기가 더 빠르다고 할 수 있는지를 유의수준 5%하에서 검정하시오

## 괜히 정규분포랑 분산을 언급하는게 아님
## 정규성,등분산성 언급? -> 독립 표본 검정 ttest_ind() ㅇㅇ# 스마트폰 배터리의 충전 시간을 줄이기 위한 새로운 충전기를 개발했다.
# 개발된 충전기의 효과를 검정하기 위해 스마트폰 사용자 집단을 두 그룹으로 나눠 한 그룹에는 새로운 충전기를 제공하고, 다른 그룹에는 기존의 충전기를 제공했다. -> 독립인 2 그룹
# 그 후 두 그룹의 평균 충전 완료 시간을 비교했다.
# 두 그룹 모두 충전 시간은 정규 분포를 따르며 분산은 같다고 가정한다.
# 새로운 충전기가 더 빠르다고 할 수 있는지를 유의수준 5%하에서 검정하시오

## 괜히 정규분포랑 분산을 언급하는게 아님
## 정규성,등분산성 언급? -> 독립 표본 검정 ttest_ind() ㅇㅇ
# 귀무: 효과가 없다
# 대립: 새로운 충전기가 더 빠르다 = 평균 충전 완료 시간이 적다

import pandas as pd
df = pd.DataFrame({
    '충전기': ['New'] * 10 + ['Old'] * 10,
    '충전시간': [
        1.5, 1.6, 1.4, 1.7, 1.5, 1.6, 1.7, 1.4, 1.6, 1.5,
        1.7, 1.8, 1.7, 1.9, 1.8, 1.7, 1.8, 1.9, 1.7, 1.6
    ]
})

# 1. 위의 가설을 검정하기 위한 검정 통계량을 구하시오.
from scipy import stats
statistics, p_value = stats.ttest_ind(df[df['충전기'] == "New"]['충전시간'], df[df['충전기'] == "Old"]['충전시간'], alternative='less')
print(statistics)
# 2. 위의 통계량에 대한 p-value를 구하시오.
print(p_value)
# 3. 유의수준 0.05하에서 귀무가설을 기준으로 검정의 결과를 채택/기각 중 선택해 입력하시오.
print("기ㅏㄱㄱ")
# Out:
# -4.582575694955849
# 0.00011546547787696304
# 기ㅏㄱㄱ

# %%
# 데이터
import pandas as pd
df = pd.DataFrame({
    '충전기': ['New'] * 10 + ['Old'] * 10,
    '충전시간': [
        1.5, 1.6, 1.4, 1.7, 1.5, 1.6, 1.7, 1.4, 1.6, 1.5,
        1.7, 1.8, 1.7, 1.9, 1.8, 1.7, 1.8, 1.9, 1.7, 1.6
    ]
})
print(df.head(2))
# Out:
#    충전기  충전시간
# 0  New   1.5
# 1  New   1.6

# %%
# 1~3. 독립 표본 t-검정
new_cond = df['충전기'] == 'New'
old_cond = df['충전기'] == 'Old'
print(stats.ttest_ind(df[new_cond]['충전시간'], df[old_cond]['충전시간'], alternative='less', equal_var=True))
# Out:
# TtestResult(statistic=-4.582575694955849, pvalue=0.00011546547787696304, df=18.0)

# %% [markdown]
# ### Section3.

# %%
# 데이터
import pandas as pd
df = pd.DataFrame({
    'User': list(range(1, 11)),
    '기존방법': [60.4, 60.7, 60.5, 60.3, 60.8, 60.6, 60.2, 60.5, 60.7, 60.4],
    '새로운방법': [59.8, 60.2, 60.1, 59.9, 59.7, 58.4, 57.0, 60.3, 59.6, 59.8]
})
# print(df.head(2))
# u0 = 새로운-기존의 평균
# 1. U0의 표본평균
df['diff'] = df['기존방법'] - df['새로운방법']
print(df['diff'].mean())
# 2. 검정통계량
import scipy
# s, p =
print(scipy.stats.ttest_rel(df['새로운방법'],df['기존방법'], alternative='less'))
# print(s)
# 3. P-VALUE
# print(p)
# 4. 기각/채택
print("chaetaek")
# Out:
# 1.0300000000000005
# TtestResult(statistic=np.float64(-3.407973078114844), pvalue=np.float64(0.0038872633380070652), df=np.int64(9))
# chaetaek

# %%
# 1. 표본 평균
df['diff'] = df['새로운방법'] - df['기존방법']
print(df['diff'].mean())

# 2~4. 대응 표본 t-검정
print(stats.ttest_rel(df['새로운방법'], df['기존방법'], alternative='less'))
# Out:
# -1.0300000000000005
# TtestResult(statistic=-3.407973078114844, pvalue=0.0038872633380070652, df=9)

# %% [markdown]
# ### Section4.

# %%
import pandas as pd
# df = pd.read_csv("math.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part3/ch6/math.csv")
# print(df.head())

# 1. 각 그룹의 수학 성적에 대해 정규성을 확인
from scipy import stats
A = df[df['groups'] == 'group_A']['scores']
B = df[df['groups'] == 'group_B']['scores']
C = df[df['groups'] == 'group_C']['scores']
D = df[df['groups'] == 'group_D']['scores']
print(stats.shapiro(A)[1])
print(stats.shapiro(B)[1])
print(stats.shapiro(C)[1])
print(stats.shapiro(D)[1])

# 2. 등분산성을 확인
print(stats.levene(A, B, C, D)[1])

# 3. 기각/채택
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
model = ols('scores~groups',df).fit()
print(anova_lm(model))
print("기각")

# 4. 그룹변수의 자유도
print(3)

# 5. 잔차으 ㅣ자유도
print(36)

# 6. 성적의 제곱합
print(411.8)

# 7. 성적의 평균 제곱
print(137.266667)

# 8. F통계량 값
print(34.174274)

# 9. pValue
print(format(1.240642e-10, ".14f"))
# Out:
# 0.9051800443853569
# 0.6678172590861611
# 0.44732595113862045
# 0.25824165549017347
# 0.17270284963232108
#             df  sum_sq     mean_sq          F        PR(>F)
# groups     3.0   411.8  137.266667  34.174274  1.240642e-10
# Residual  36.0   144.6    4.016667        NaN           NaN
# 기각
# 3
# 36
# 411.8
# 137.266667
# 34.174274
# 0.00000000012406

# %%
from scipy import stats

# 1. Shapiro-Wilk 검정 (정규성)
condA = df['groups']=='group_A'
print(stats.shapiro(df[condA]['scores']))

condB = df['groups']=='group_B'
print(stats.shapiro(df[condB]['scores']))

condC = df['groups']=='group_C'
print(stats.shapiro(df[condC]['scores']))

condD = df['groups']=='group_D'
print(stats.shapiro(df[condD]['scores']))

# 2. Levene 검정 (등분산성)
print(stats.levene(df[condA]['scores'], df[condB]['scores'], df[condC]['scores'], df[condD]['scores']))
# Out:
# ShapiroResult(statistic=0.9715896670696531, pvalue=0.9051800443853569)
# ShapiroResult(statistic=0.9499422438060351, pvalue=0.6678172590861611)
# ShapiroResult(statistic=0.9299424104842702, pvalue=0.44732595113862045)
# ShapiroResult(statistic=0.9065684572704982, pvalue=0.25824165549017347)
# LeveneResult(statistic=1.757685352622062, pvalue=0.17270284963232108)

# %%
# 일원분산분석을 위한 모델 학습
from statsmodels.formula.api import ols
model = ols('scores ~ groups', df).fit()

# 3~9. ANOVA 테이블
from statsmodels.stats.anova import anova_lm
print(anova_lm(model))
# Out:
#             df  sum_sq     mean_sq          F        PR(>F)
# groups     3.0   411.8  137.266667  34.174274  1.240642e-10
# Residual  36.0   144.6    4.016667        NaN           NaN

# %% [markdown]
# ### Section5.

# %%
# H 토마토 연구소에는 수확량을 늘리기 위해 세가지 다른 비료 유형과 네가지 다른 물 주기를 실험한다.
# 연구소는 12개의 토마토 식물을 무작위로 선택해 반복적으로 실험을 수행햇다
import pandas as pd
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part3/ch6/tomato2.csv")

# %%
# 1. 비료 유형에 따른 수확량의 평균에 차이가 있는지를 검정하시오.
# model = ols('수확량 ~ 비료유형',df).fit()
# print(anova_lm(model))
# print(3.204, 0.053, 귀무채택)
# 2. 물 주기에 따른 토마토 수확량의 평균에 차이가 있는지를 검정하시오.
# model = ols('수확량 ~ 물주기',df).fit()
# print(anova_lm(model))
# print()
# 3. 비료 유형과 물 주기 간의 상호작용이 토마토 수확량에 영향이 있는지 검정하시오.
model = ols('수확량 ~ C(비료유형) + C(물주기) + C(비료유형):C(물주기)',df).fit()
print(anova_lm(model))
# Out:
#                   df        sum_sq      mean_sq         F    PR(>F)
# C(비료유형)          2.0   5251.722222  2625.861111  3.184685  0.059334
# C(물주기)           3.0   9057.000000  3019.000000  3.661490  0.026460
# C(비료유형):C(물주기)   6.0   4271.833333   711.972222  0.863491  0.535426
# Residual        24.0  19788.666667   824.527778       NaN       NaN

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# 1~9 이원 분산 분석
models = ols('수확량 ~ C(비료유형) * C(물주기)', data=df).fit()
anova_table = sm.stats.anova_lm(models)
print(anova_table)
# Out:
#                   df        sum_sq      mean_sq         F    PR(>F)
# C(비료유형)          2.0   5251.722222  2625.861111  3.184685  0.059334
# C(물주기)           3.0   9057.000000  3019.000000  3.661490  0.026460
# C(비료유형):C(물주기)   6.0   4271.833333   711.972222  0.863491  0.535426
# Residual        24.0  19788.666667   824.527778       NaN       NaN

# %% [markdown]
# ### Section6.

# %%
from scipy imort stats
stats.chisuare()

# %%
# 1. 교통사고 5회 이상 경험 비율
print(30 / 1000)

# 2~4. 적합도 검정
from scipy.stats import chisquare
observed = [550, 250, 100, 70, 30]
expected = [1000*0.60, 1000*0.25, 1000*0.08, 1000*0.05, 1000*0.02]
print(chisquare(observed, expected))
# Out:
# 0.03
# Power_divergenceResult(statistic=22.166666666666668, pvalue=0.00018567620386641427)

# %% [markdown]
# ### Section7.

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# 1~3. 독립성 검정
observed = pd.DataFrame([[50, 30], [60, 40]])
print(chi2_contingency(observed))
# Out:
# Chi2ContingencyResult(statistic=np.float64(0.03535714285714309), pvalue=np.float64(0.8508492527705047), dof=1, expected_freq=array([[48.88888889, 31.11111111],
#        [61.11111111, 38.88888889]]))

# %%
# 데이터
import pandas as pd
df = pd.DataFrame({
        '캠프': ['빅분기']*80 + ['정처기']*100,
        '등록여부': ['등록']*50 + ['등록안함']*30 + ['등록']*60 + ['등록안함']*40
})
print(df.head())
df = pd.crosstab(df['캠프'], df['등록여부'])
chi2_contingency(df)
# Out:
#     캠프 등록여부
# 0  빅분기   등록
# 1  빅분기   등록
# 2  빅분기   등록
# 3  빅분기   등록
# 4  빅분기   등록
# Chi2ContingencyResult(statistic=np.float64(0.03535714285714309), pvalue=np.float64(0.8508492527705047), dof=1, expected_freq=array([[48.88888889, 31.11111111],
#        [61.11111111, 38.88888889]]))

# %%
# 교차표로 변경
df = pd.crosstab(df['캠프'], df['등록여부'])
print(df)

# 4~6. 독립성 검정
print(chi2_contingency(df))
# Out:
# 등록여부  등록  등록안함
# 캠프
# 빅분기   50    30
# 정처기   60    40
# Chi2ContingencyResult(statistic=0.03535714285714309, pvalue=0.8508492527705047, dof=1, expected_freq=array([[48.88888889, 31.11111111],
#        [61.11111111, 38.88888889]]))

# %% [markdown]
# ### Section8.

# %%
# 데이터
import pandas as pd
df = pd.DataFrame({
    '할인율': [28, 24, 13, 0, 27, 30, 10, 16, 6, 5, 7, 11, 11, 30, 25,
            4, 7, 24, 19, 21, 6, 10, 26, 13, 15, 6, 12, 6, 20, 2],
    '온도': [15, 34, 15, 22, 29, 30, 14, 17, 28, 29, 19, 19, 34, 10,
           29, 28, 12, 25, 32, 28, 22, 16, 30, 11, 16, 18, 16, 33, 12, 22],
    '광고비': [342, 666, 224, 764, 148, 499, 711, 596, 797, 484, 986, 347, 146, 362, 642,
            591, 846, 260, 560, 941, 469, 309, 730, 305, 892, 147, 887, 526, 525, 884],
    '주문량': [635, 958, 525, 25, 607, 872, 858, 732, 1082, 863, 904, 686, 699, 615, 893,
            830, 856, 679, 918, 951, 789, 583, 988, 631, 866, 549, 910, 946, 647, 943]
})
# print(df.head(3))

from scipy import stats
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
model = ols('주문량~할인율 + 온도 + 광고비', df).fit()

# 1.
print(round(stats.pearsonr(df['할인율'], df['온도'])[0] ,2))

# 2.
print(model.rsquared.round(2))

# 3.
print(model.params)

# 5.
print(model.pvalues)

# 6.
new = pd.DataFrame({'할인율':[10],
                    '온도':[20],
                    '광고비':[500]})
print(model.predict(new))

# 7.
print((model.resid**2).sum())

# 8.
print((model.resid**2).mean())

# 9.
print(model.conf_int(0.1))

# 10.
new1 = pd.DataFrame({'할인율':[15],
                    '온도':[25],
                    '광고비':[300]})
print(model.get_prediction(new1).summary_frame(0.1))

# 11
# Out:
# 0.09
# 0.4
# Intercept    267.660902
# 할인율            4.206829
# 온도             9.479843
# 광고비            0.414827
# dtype: float64
# Intercept    0.049625
# 할인율          0.246660
# 온도           0.028867
# 광고비          0.002740
# dtype: float64
# 0    706.739338
# dtype: float64
# 732197.8988142073
# 24406.596627140243
#                    0           1
# Intercept  45.955720  489.366084
# 할인율        -1.847229   10.260887
# 온도          2.490702   16.468984
# 광고비         0.201064    0.628589
#          mean    mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  692.207386  45.555397     614.507283     769.907488    395.622293
#
#    obs_ci_upper
# 0    988.792478

# %%
# 다중 선형 회귀 모델 적합
from statsmodels.formula.api import ols
model = ols('주문량 ~ 할인율 + 온도 + 광고비', data=df).fit()

# 1. 상관계수
print("1. 상관계수:", round(df['할인율'].corr(df['온도']), 2))

# 2. 결정계수
print("2. 결정계수(R-squared):", round(model.rsquared, 2))

# 3. 회귀계수(기울기)
print("3. 회귀계수:", round(model.params, 4))

# 4. 절편
print("4. 절편:", round(model.params['Intercept'], 4))

# 5. 회귀계수 검정
print("5. pvalue:", round(model.pvalues['온도'], 4))

# 6. 예측 판매량
new_data = pd.DataFrame({"할인율": [10], "온도": [20], "광고비": [500]})
result = model.predict(new_data)
print("6. 새로운 데이터:", int(result[0]))

# 7. 잔차 제곱합
df['잔차'] = df['주문량'] - model.predict(df)
print("7. 잔차 제곱합:", round(sum(df['잔차']**2), 2))

# 8. MSE(Mean Squared Error)
MSE = (df['잔차'] ** 2).mean()
print('8. MSE:', round(MSE, 4))

# 9. 각 변수에 대한 90% 신뢰구간
print("9. 신뢰구간:\n", model.conf_int(alpha=0.1))

# 10. 새로운 데이터의 예측값의 90% 신뢰구간과 예측구간
new_data = pd.DataFrame({"할인율": [15], "온도": [25], "광고비": [300]})
pred = model.get_prediction(new_data)
result = pred.summary_frame(alpha=0.1)
print("10. 예측값의 신뢰구간과 예측구간:\n", result)

# 11. 광고비는 배달 주문량에 영향을 주는지 가설 검정
cond = model.pvalues['광고비'] < 0.05
if cond:
    result = "기각"
else:
    result = "채택"
print("11. 귀무가설", result)

# 선형 회귀 모델의 요약 결과
print(model.summary())
# Out:
# 1. 상관계수: 0.09
# 2. 결정계수(R-squared): 0.4
# 3. 회귀계수: Intercept    267.6609
# 할인율            4.2068
# 온도             9.4798
# 광고비            0.4148
# dtype: float64
# 4. 절편: 267.6609
# 5. pvalue: 0.0289
# 6. 새로운 데이터: 706
# 7. 잔차 제곱합: 732197.9
# 8. MSE: 24406.5966
# 9. 신뢰구간:
#                     0           1
# Intercept  45.955720  489.366084
# 할인율        -1.847229   10.260887
# 온도          2.490702   16.468984
# 광고비         0.201064    0.628589
# 10. 예측값의 신뢰구간과 예측구간:
#           mean    mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  692.207386  45.555397     614.507283     769.907488    395.622293
#
#    obs_ci_upper
# 0    988.792478
# 11. 귀무가설 기각
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    주문량   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.330
# Method:                 Least Squares   F-statistic:                     5.770
# Date:                Thu, 27 Nov 2025   Prob (F-statistic):            0.00366
# Time:                        14:04:12   Log-Likelihood:                -194.11
# No. Observations:                  30   AIC:                             396.2
# Df Residuals:                      26   BIC:                             401.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    267.6609    129.985      2.059      0.050       0.472     534.849
# 할인율            4.2068      3.549      1.185      0.247      -3.089      11.503
# 온도             9.4798      4.098      2.313      0.029       1.057      17.903
# 광고비            0.4148      0.125      3.310      0.003       0.157       0.672
# ==============================================================================
# Omnibus:                       56.788   Durbin-Watson:                   1.647
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              419.005
# Skew:                          -3.845   Prob(JB):                     1.03e-91
# Kurtosis:                      19.616   Cond. No.                     2.58e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Section9.

# %%
import pandas as pd
# df = pd.read_csv("customer_travel.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/refs/heads/main/part3/ch6/customer_travel.csv")

# df.head()
a = df.iloc[:len(df)//2]
b = df.iloc[len(df)//2:]

# 1. 종속변수와 모든 독립변수를 사용하여 로지스틱 회귀 모델을 적합하고ㅡ 유의하지 않은 독립변수의 개수를 구하시오.
from statsmodels.formula.api import logit
model = logit('target ~ age + service + social + booked', a).fit()

print("1. ",(model.pvalues[1:]> 0.05).sum())

# 2. p-value가 0.05보다 작은 유의한변수만 사용하여 수정된 모델을 만들고 적합하시오. 이 수정된 모델에서 가장 큰 p-value를 가진 변수의 이름을 구하시오
# age, booked
a.drop(columns=['service', 'social'], axis=1)
model_v2 = logit('target ~ age + booked', a).fit()
print("2. ",model_v2.pvalues[1:].idxmax())

# 3. 수정된 모델에서 독립변수 중 절댓값이 가장 큰 회귀계수를 가진 변수의 이름을 구하시오.
print("3.",abs(model_v2.params[1:]).idxmax())

# 4. 수정된 모델에서 로그 우도를 구하시오.
print("4. ",model_v2.llf)

# 5. 수정된 모델에서 잔차이탈도를 구하시오
## 잔차이탈도 = 로그우도 * -2
print("5. ",model_v2.llf*-2)

# 6. 수저된모델에서 'booked'변수가 3 증가할 떄 오즈비를 계산하시오.
import numpy as np
print("6. ", np.exp(model_v2.params['booked']*3))

# 7. 수정된 모델에서 p-value가 0.05 보다 작은 회귀계수의 총합을 구하시오. 단 상수항 회귀계수도 유의할 경우 포함하시오
print("7. ",model_v2.params[model_v2.pvalues < 0.05].sum())

# 8. 수저된 모델로 b데이터를 사용해 예측한 후, b데이터의 target과 비교해 정확도를 계산하시오.
pred = model_v2.predict(b)
pred = (pred > 0.5).astype(int)
from sklearn.metrics import accuracy_score
ac = accuracy_score(b['target'], pred)
print("8.",ac)
# 9. 8에서 계산한 정확도를 바탕으로 오류율을 계산하시오
## 오류율 = 1 - ac
print("9. ", 1 - ac)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.527521
#          Iterations 6
# 1.  2
# Optimization terminated successfully.
#          Current function value: 0.528581
#          Iterations 6
# 2.  age
# 3. booked
# 4.  -211.4323825144558
# 5.  422.8647650289116
# 6.  0.058533122917711476
# 7.  1.409468270586192
# 8. 0.765
# 9.  0.235

# %%
import pandas as pd
# df = pd.read_csv("customer_travel.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/refs/heads/main/part3/ch6/customer_travel.csv")

# df.head()
a = df.iloc[:len(df)//2]
b = df.iloc[len(df)//2:]

# 1. 종속변수와 모든 독립변수를 사용하여 로지스틱 회귀 모델을 적합하고ㅡ 유의하지 않은 독립변수의 개수를 구하시오.
from statsmodels.formula.api import logit
model = logit('target ~ age + service + social + booked', a).fit()

pred = model.predict(b)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.527521
#          Iterations 6
# 400    0.140491
# 401    0.184996
# 402    0.126517
# 403    0.330159
# 404    0.231889
#          ...
# 795    0.118955
# 796    0.363397
# 797    0.395322
# 798    0.080388
# 799    0.399294
# Length: 400, dtype: float64

# %%
# 데이터 분할
midpoint = len(df) // 2 #몫(정수)
a = df.iloc[:midpoint]
b = df.iloc[midpoint:]

# 데이터 확인
a.shape, b.shape
# Out:
# ((400, 5), (400, 5))

# %%
# 1) 유의하지 않은 독립변수의 개수
from statsmodels.formula.api import logit
formula = "target ~ age + service + social + booked"
model = logit(formula, data=a).fit()
# print(model.summary())
print("1.", sum(model.pvalues[1:] >= 0.05)) # 상수항(Intercept) 제외

# 2. 수정된 모델에서 가장 큰 p-value를 가진 변수의 이름
formula = 'target ~ age + booked'
model = logit(formula, data=a).fit()
# print(model.summary())
print("2.", model.pvalues[1:].idxmax()) # 상수항(Intercept) 제외

# 3. 수정된 모델에서 독립변수 중 절댓값이 가장 큰 회귀계수를 가진 변수의 이름
print("3.", model.params[1:].abs().idxmax())

# 4. 로그 우도
print("4.", model.llf)

# 5. 잔차이탈도
print("5.", -2 * model.llf)

# 6. 'booked' 변수가 3 증가할 때 오즈비
import numpy as np
print("6.", np.exp(model.params['booked'] * 3))

# 7. p-value가 0.05보다 작은 회귀계수의 총합
print("7.", model.params[model.pvalues < 0.05].sum()) # 상수항(절편)도 포함

# 8. 정확도
pred = model.predict(b)
pred = (pred > 0.5).astype(int)
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(b['target'], pred)
print("8.", accuracy)

# 9. 오류율
error_rate = 1 - accuracy
error_rate
print("9.", error_rate)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.527521
#          Iterations 6
# 1. 2
# Optimization terminated successfully.
#          Current function value: 0.528581
#          Iterations 6
# 2. age
# 3. booked
# 4. -211.4323825144558
# 5. 422.8647650289116
# 6. 0.058533122917711476
# 7. 1.409468270586192
# 8. 0.765
# 9. 0.235
