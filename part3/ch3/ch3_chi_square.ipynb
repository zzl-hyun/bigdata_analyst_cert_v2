# %% [markdown]
# [구글 코랩(Colab)에서 실행하기](https://colab.research.google.com/github/lovedlim/bigdata_analyst_cert_v2/blob/main/part3/ch3/ch3_chi_square.ipynb)

# %% [markdown]
# # 1. 적합도 검정

# %%
# 어떤 도시에서 300명을 대상으로 아이스크림 맛 선호도를 조사했다. 
# 이 도시에서 조사된 아이스크림 맛 선호도는 바닐라: 150, 초코: 120, 딸기: 30이었다.
# 전국적인 아이스크림 맛 선호도 조사 결과를 통해 알려진 비율은 바닐라 50%, 초코 35%, 딸기 15%로 알려져 있다.
# 이 도시의 아이스크림 맛 선호도는 전국적인 맛 선호도와 차이가 있는가?

observed = [150, 120, 30]
expected = [0.5*300, 0.35*300, 0.15*300]

from scipy import stats
stats.chisquare(observed, expected)
# Out:
# Power_divergenceResult(statistic=7.142857142857142, pvalue=0.028115659748972056)

# %%
from scipy import stats

observed = [150, 120, 30]
expected = [0.5*300, 0.35*300, 0.15*300]
print(stats.chisquare(observed, expected))
# Out:
# Power_divergenceResult(statistic=7.142857142857142, pvalue=0.028115659748972056)

# %% [markdown]
# # 2. 독립성 검정

# %% [markdown]
# ## 2-1 교차표 데이터

# %%
# 성별에 따라 우농을 좋아하는지 조사한 결과다. 성별과 운동 선호도가 독립적인지 가설검정
# 귀무 성별과 운동은 독립
# 대립: 성별 - 운동은 연관잇다
import pandas as pd
table = pd.DataFrame({'좋아함': [80, 30],
                      '좋아하지 않음':[90, 10]},
                      index=['남자', '여자'])
from scipy import stats
stats.chi2_contingency(table)
stats.mannwhitneyU
# Out:
# Chi2ContingencyResult(statistic=9.045792112299468, pvalue=0.0026330012530379632, dof=1, expected_freq=array([[89.04761905, 80.95238095],
#        [20.95238095, 19.04761905]]))
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
df = pd.DataFrame({'좋아함': [80, 90],
                   '좋아하지 않음': [30, 10]},
                  index=['남자', '여자'])
print(df)

from scipy.stats import ttest_1samp, ttest_rel, ttest_ind, f_oneway, chisquare, chi2_contingency
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
# Out:
#     좋아함  좋아하지 않음
# 남자   80       30
# 여자   90       10

# %%
df = pd.DataFrame([[80, 30], [90, 10]],
                  columns=['좋아함','좋아하지 않음'],
                  index=['남자', '여자'])
print(df)
# Out:
#     좋아함  좋아하지 않음
# 남자   80       30
# 여자   90       10

# %%
# df = [[80, 30], [90, 10]]

# %%
from scipy import stats
print(stats.chi2_contingency(df))
# Out:
# Chi2ContingencyResult(statistic=9.045792112299468, pvalue=0.0026330012530379632, dof=1, expected_freq=array([[89.04761905, 20.95238095],
#        [80.95238095, 19.04761905]]))

# %% [markdown]
# ## 2-2 로우 데이터

# %%
import pandas as pd
data = {
    '성별': ['남자']*110 + ['여자']*100,
    '운동': ['좋아함']*80 + ['좋아하지 않음']*30 + ['좋아함']*90 + ['좋아하지 않음']*10
}
df = pd.DataFrame(data)
print(df.head(3))
# Out:
#    성별   운동
# 0  남자  좋아함
# 1  남자  좋아함
# 2  남자  좋아함

# %%
df = pd.crosstab(df['성별'], df['운동'])
df
# Out:
# 운동  좋아하지 않음  좋아함
# 성별
# 남자       30   80
# 여자       10   90

# %%
from scipy.stats import chi2_contingency
print(chi2_contingency(df))
# Out:
# Chi2ContingencyResult(statistic=9.045792112299468, pvalue=0.0026330012530379632, dof=1, expected_freq=array([[20.95238095, 89.04761905],
#        [19.04761905, 80.95238095]]))

# %% [markdown]
# # 3.동질성 검정

# %% [markdown]
# ## 3-1 교차표 데이터

# %%
import pandas as pd
from scipy import stats
df = pd.DataFrame([[50, 50], [30, 70]])
print(stats.chi2_contingency(df))
# Out:
# Chi2ContingencyResult(statistic=7.520833333333334, pvalue=0.006098945931214352, dof=1, expected_freq=array([[40., 60.],
#        [40., 60.]]))

# %% [markdown]
# ## 3-2 로우 데이터

# %%
import pandas as pd
data = {
    '학과': ['통계학과']*100 + ['컴퓨터공학과']*100,
    '동아리가입여부': ['가입']*50 + ['미가입']*50 + ['가입']*30 + ['미가입']*70
}
df = pd.DataFrame(data)
df.sample(5)
# Out:
#          학과 동아리가입여부
# 94     통계학과     미가입
# 116  컴퓨터공학과      가입
# 154  컴퓨터공학과     미가입
# 60     통계학과     미가입
# 197  컴퓨터공학과     미가입

# %%
df = pd.crosstab(df['학과'], df['동아리가입여부'])
df
# Out:
# 동아리가입여부  가입  미가입
# 학과
# 컴퓨터공학과   30   70
# 통계학과     50   50

# %%
from scipy import stats
print(stats.chi2_contingency(df))
# Out:
# Chi2ContingencyResult(statistic=7.520833333333334, pvalue=0.006098945931214352, dof=1, expected_freq=array([[40., 60.],
#        [40., 60.]]))
